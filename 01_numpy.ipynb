# %% [markdown]
# <a href="https://colab.research.google.com/github/adam-klimas/data-science-bootcamp/blob/main/01_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
np.__version__
# Out:
# '2.0.2'

# %%
print(dir(np))

# %%
help(np.array)

# %%
x = np.array([1, 3])
x
# Out:
# array([1, 3])

# %%
print(x)
# Out:
# [1 3]

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x.ndim
# Out:
# 1

# %%
x.shape
# Out:
# (2,)

# %%
x.size
# Out:
# 2

# %%
x.dtype
# Out:
# dtype('int64')

# %%
y = np.array([1.2, 3.3, 5.1])
y
# Out:
# array([1.2, 3.3, 5.1])

# %%
y.shape
# Out:
# (3,)

# %%
y.size
# Out:
# 3

# %%
y.dtype
# Out:
# dtype('float64')

# %%
z = np.array([[1, 2], [4, 2]])
z
# Out:
# array([[1, 2],
#        [4, 2]])

# %%
z.size
# Out:
# 4

# %%
z.shape
# Out:
# (2, 2)

# %%
z.dtype
# Out:
# dtype('int64')
